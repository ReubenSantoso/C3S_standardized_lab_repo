# %% [markdown]
# # About
#
# This noteboook is a sample on how to use the c3sdb module to standardize training, validation, and test code.

# %%
from c3sdb import C3SDB

# %%
# Then use it like:
model = C3SDB("C3S_clean_smile.db")

# %%
model.build_features(feature_columns=["adduct", "mz"], target_column="ccs", use_mqns=True)

# %%
#checking feature building
print(model.X_columns)
print(model.y_column)
print(model.db.columns)
# Out:
# ['mz', 'adduct_[M+CH3COO]-', 'adduct_[M+H-H2O]+', 'adduct_[M+HCOO]-', 'adduct_[M+H]+', 'adduct_[M+K]+', 'adduct_[M+NH4]+', 'adduct_[M+Na-2H]-', 'adduct_[M+Na]+', 'adduct_[M-H]-', 'adduct_other', 'adv', 'hac', 'hbam', 'c', 'asb', 'hba', 'adb', 'hbd', 'cdv', 'ao']
# ccs
# Index(['g_id', 'name', 'adduct', 'mass', 'z', 'mz', 'ccs', 'smi',
#        'chem_class_label', 'src_tag', 'ccs_type', 'ccs_method', 'c', 'f', 'cl',
#        'br', 'i', 's', 'p', 'an', 'cn', 'ao', 'co', 'hac', 'hbam', 'hba',
#        'hbdm', 'hbd', 'neg', 'pos', 'asb', 'adb', 'atb', 'csb', 'cdb', 'ctb',
#        'rbc', 'asv', 'adv', 'atv', 'aqv', 'cdv', 'ctv', 'cqv', 'r3', 'r4',
#        'r5', 'r6', 'r7', 'r8', 'r9', 'rg10', 'afr', 'bfr',
#        'adduct_[M+CH3COO]-', 'adduct_[M+H-H2O]+', 'adduct_[M+HCOO]-',
#        'adduct_[M+H]+', 'adduct_[M+K]+', 'adduct_[M+NH4]+',
#        'adduct_[M+Na-2H]-', 'adduct_[M+Na]+', 'adduct_[M-H]-', 'adduct_other',
#        'adduct_[M+CH3COO]-', 'adduct_[M+H-H2O]+', 'adduct_[M+HCOO]-',
#        'adduct_[M+H]+', 'adduct_[M+K]+', 'adduct_[M+NH4]+',
#        'adduct_[M+Na-2H]-', 'adduct_[M+Na]+', 'adduct_[M-H]-', 'adduct_other'],
#       dtype='object')

# %%
model.train_test_split(stratify="source") #stratisfy on source
# model.train_test_split() #stratisfy on ccs
# Out:
# (               mz  adduct_[M+CH3COO]-  adduct_[M+CH3COO]-  adduct_[M+H-H2O]+  \
#  5437   586.228300                 0.0                 0.0                0.0
#  11541  298.217100                 0.0                 0.0                0.0
#  12606  483.001600                 0.0                 0.0                0.0
#  7501   834.600000                 0.0                 0.0                0.0
#  11795  496.101000                 0.0                 0.0                0.0
#  ...           ...                 ...                 ...                ...
#  4709   559.303000                 0.0                 0.0                0.0
#  14382  826.629591                 0.0                 0.0                0.0
#  2273   400.196600                 0.0                 0.0                0.0
#  6893   844.739400                 0.0                 0.0                0.0
#  6595   722.506800                 0.0                 0.0                0.0
#
#         adduct_[M+H-H2O]+  adduct_[M+HCOO]-  adduct_[M+HCOO]-  adduct_[M+H]+  \
#  5437                 0.0               0.0               0.0            1.0
#  11541                0.0               0.0               0.0            1.0
#  12606                0.0               0.0               0.0            0.0
#  7501                 0.0               0.0               0.0            1.0
#  11795                0.0               0.0               0.0            0.0
#  ...                  ...               ...               ...            ...
#  4709                 0.0               0.0               0.0            0.0
#  14382                0.0               0.0               0.0            0.0
#  2273                 0.0               0.0               0.0            0.0
#  6893                 0.0               0.0               0.0            0.0
#  6595                 0.0               0.0               0.0            0.0
#
#         adduct_[M+H]+  adduct_[M+K]+  ...  adv  hac  hbam   c  asb  hba  adb  \
#  5437             1.0            0.0  ...    3   42    16  30    5    3   23
#  11541            1.0            0.0  ...    7   22    11  20    9    0    3
#  12606            0.0            1.0  ...    2   29    12  19    5    1   16
#  7501             1.0            0.0  ...   44   58    48  48   40    9   17
#  11795            0.0            1.0  ...    1   33    11  23    5    3   19
#  ...              ...            ...  ...  ...  ...   ...  ..  ...  ...  ...
#  4709             0.0            0.0  ...    2   39    14  33    3    3   12
#  14382            0.0            0.0  ...   28   55    51  45   37    3   18
#  2273             0.0            0.0  ...    3   27    11  19    3    2   16
#  6893             0.0            0.0  ...   49   59    51  53   45    7   12
#  6595             0.0            0.0  ...   39   48    42  39   37    5   15
#
#         hbd  cdv  ao
#  5437    21    6  10
#  11541    6    9   1
#  12606   12    7   7
#  7501     0    0   8
#  11795   16   10   8
#  ...    ...  ...  ..
#  4709    22   10   6
#  14382    0    0   8
#  2273    16    5   6
#  6893     0    0   6
#  6595     0    0   7
#
#  [10577 rows x 31 columns],
#  5437     30
#  11541    20
#  12606    19
#  7501     48
#  11795    23
#           ..
#  4709     33
#  14382    45
#  2273     19
#  6893     53
#  6595     39
#  Name: c, Length: 10577, dtype: int64,
#                 mz  adduct_[M+CH3COO]-  adduct_[M+CH3COO]-  adduct_[M+H-H2O]+  \
#  7656   846.620000                 0.0                 0.0                0.0
#  5057   370.237700                 0.0                 0.0                0.0
#  7028   954.844700                 0.0                 0.0                0.0
#  14040  740.522453                 0.0                 0.0                0.0
#  16976  313.180300                 0.0                 0.0                0.0
#  ...           ...                 ...                 ...                ...
#  8319   710.576000                 0.0                 0.0                0.0
#  9969   453.231620                 0.0                 0.0                0.0
#  1682   318.051892                 0.0                 0.0                0.0
#  9648   332.070000                 0.0                 0.0                0.0
#  12292  242.021900                 0.0                 0.0                0.0
#
#         adduct_[M+H-H2O]+  adduct_[M+HCOO]-  adduct_[M+HCOO]-  adduct_[M+H]+  \
#  7656                 0.0               0.0               0.0            1.0
#  5057                 0.0               0.0               0.0            1.0
#  7028                 0.0               0.0               0.0            0.0
#  14040                0.0               0.0               0.0            1.0
#  16976                0.0               0.0               0.0            1.0
#  ...                  ...               ...               ...            ...
#  8319                 0.0               0.0               0.0            0.0
#  9969                 0.0               0.0               0.0            0.0
#  1682                 0.0               0.0               0.0            0.0
#  9648                 0.0               0.0               0.0            1.0
#  12292                0.0               0.0               0.0            0.0
#
#         adduct_[M+H]+  adduct_[M+K]+  ...  adv  hac  hbam   c  asb  hba  adb  \
#  7656             1.0            0.0  ...   48   59    48  49   42   10   17
#  5057             1.0            0.0  ...    4   27     7  23    2    2    7
#  7028             0.0            0.0  ...   57   67    58  61   52    8   12
#  14040            1.0            0.0  ...   40   51    43  41   37    7   18
#  16976            1.0            0.0  ...    0   23     5  20    1    1    6
#  ...              ...            ...  ...  ...  ...   ...  ..  ...  ...  ...
#  8319             0.0            0.0  ...   42   50    39  45   34   10   10
#  9969             0.0            0.0  ...    3   31    11  23    6    3   14
#  1682             0.0            0.0  ...    2   20     7  12    4    3   11
#  9648             1.0            0.0  ...    2   23     6  15    3    3   11
#  12292            0.0            1.0  ...    1   15     3  11    1    2    7
#
#         hbd  cdv  ao
#  7656     0    0   8
#  5057    19    9   3
#  7028     0    0   6
#  14040    0    0   8
#  16976   16    8   2
#  ...    ...  ...  ..
#  8319     0    0   5
#  9969    20    8   7
#  1682     6    7   3
#  9648     8   10   4
#  12292    6    6   2
#
#  [1764 rows x 31 columns],
#  7656     49
#  5057     23
#  7028     61
#  14040    41
#  16976    20
#           ..
#  8319     45
#  9969     23
#  1682     12
#  9648     15
#  12292    11
#  Name: c, Length: 1764, dtype: int64,
#                 mz  adduct_[M+CH3COO]-  adduct_[M+CH3COO]-  adduct_[M+H-H2O]+  \
#  16457  277.064700                 0.0                 0.0                0.0
#  12878  483.266500                 0.0                 0.0                0.0
#  17615  351.172600                 0.0                 0.0                0.0
#  14671  642.615917                 0.0                 0.0                0.0
#  3788   505.180000                 0.0                 0.0                0.0
#  ...           ...                 ...                 ...                ...
#  8297   636.555000                 0.0                 0.0                0.0
#  137    560.079500                 0.0                 0.0                0.0
#  13336  255.065700                 0.0                 0.0                0.0
#  4625   235.060100                 0.0                 0.0                0.0
#  9763   532.289610                 0.0                 0.0                0.0
#
#         adduct_[M+H-H2O]+  adduct_[M+HCOO]-  adduct_[M+HCOO]-  adduct_[M+H]+  \
#  16457                0.0               0.0               0.0            1.0
#  12878                0.0               0.0               0.0            0.0
#  17615                0.0               0.0               0.0            0.0
#  14671                0.0               0.0               0.0            0.0
#  3788                 0.0               0.0               0.0            1.0
#  ...                  ...               ...               ...            ...
#  8297                 0.0               0.0               0.0            0.0
#  137                  0.0               0.0               0.0            1.0
#  13336                0.0               0.0               0.0            1.0
#  4625                 0.0               0.0               0.0            1.0
#  9763                 0.0               0.0               0.0            0.0
#
#         adduct_[M+H]+  adduct_[M+K]+  ...  adv  hac  hbam   c  asb  hba  adb  \
#  16457            1.0            0.0  ...    1   19     5  13    3    3    8
#  12878            0.0            1.0  ...   11   33    17  31   11    6    4
#  17615            0.0            1.0  ...    2   23     4  21    1    1    4
#  14671            0.0            0.0  ...   38   44    41  41   37    2    5
#  3788             1.0            0.0  ...    5   34    18  18    7    0   32
#  ...              ...            ...  ...  ...  ...   ...  ..  ...  ...  ...
#  8297             0.0            0.0  ...   36   44    38  39   33    5   10
#  137              1.0            0.0  ...    6   36    20  15   12    3   33
#  13336            1.0            0.0  ...    0   19     3  15    1    1    8
#  4625             1.0            0.0  ...    2   17     5  12    3    2   10
#  9763             0.0            0.0  ...    4   33    14  26    6    2   13
#
#         hbd  cdv  ao
#  16457    6    9   3
#  12878    7    4   2
#  17615   19    9   2
#  14671    0    0   2
#  3788    18    3  13
#  ...    ...  ...  ..
#  8297     0    0   5
#  137     10    6  13
#  13336    9    9   3
#  4625     6    5   4
#  9763    20    7   6
#
#  [5290 rows x 31 columns],
#  16457    13
#  12878    31
#  17615    21
#  14671    41
#  3788     18
#           ..
#  8297     39
#  137      15
#  13336    15
#  4625     12
#  9763     26
#  Name: c, Length: 5290, dtype: int64)

# %%
# Shapes of datasets with clarifying print statements
print("Shape Of Total Dataset (features):", model.X_df.shape)
print("Shape Of Total Dataset (targets):", model.y_df.shape)

print("Shape Of Training Set (features):", model.trainX_df.shape)
print("Shape Of Training Set (targets):", model.trainY_df.shape)

print("Shape Of Test Set (features):", model.testX_df.shape)
print("Shape Of Test Set (targets):", model.testY_df.shape)

print("Shape Of Validation Set (features):", model.validationX_df.shape)
print("Shape Of Validation Set (targets):", model.validationY_df.shape)
# Out:
# Shape Of Total Dataset (features): (17631, 31)
# Shape Of Total Dataset (targets): (17631,)
# Shape Of Training Set (features): (10577, 31)
# Shape Of Training Set (targets): (10577,)
# Shape Of Test Set (features): (5290, 31)
# Shape Of Test Set (targets): (5290,)
# Shape Of Validation Set (features): (1764, 31)
# Shape Of Validation Set (targets): (1764,)

# %%
model.center_and_scale()

# %%
model.train()
model.predict()
model.compute_metrics()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 model.train()
#       2 model.predict()
#       3 model.compute_metrics()
#
# File ~/Xu_Lab_Files/C3S_standardized_lab_repo/c3s_regression_training/c3sdb.py:293, in C3SDB.train(self)
#     292 def train(self):
# --> 293     raise NotImplementedError
#
# NotImplementedError:
